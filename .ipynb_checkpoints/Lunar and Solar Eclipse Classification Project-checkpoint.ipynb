# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfLunar = pd.read_csv('datasets/lunar.csv')
dfLunar.head()
# Out:
#    Catalog Number      Calendar Date Eclipse Time  Delta T (s)  \
# 0               1      -1999 June 26     14:13:28        46437
# 1               2  -1999 November 21     20:23:49        46427
# 2               3       -1998 May 17     05:47:36        46416
# 3               4  -1998 November 11     05:15:58        46404
# 4               5        -1997 May 6     18:57:01        46392
#
#    Lunation Number  Saros Number Eclipse Type Quincena Solar Eclipse   Gamma  \
# 0           -49456            17            N                     t- -1.0981
# 1           -49451           -16            N                     -a -1.1155
# 2           -49445           -11            P                     -t  0.8988
# 3           -49439            -6            P                     -a -0.4644
# 4           -49433            -1           T+                     pp  0.1003
#
#    Penumbral Magnitude  Umbral Magnitude Latitude Longitude  \
# 0               0.8791           -0.1922      24S       22W
# 1               0.8143           -0.1921      15N       98W
# 2               1.2105            0.2069      13S       89E
# 3               2.0382            0.9740      12N      113E
# 4               2.6513            1.6963      11S       92W
#
#    Penumbral Eclipse Duration (m) Partial Eclipse Duration (m)  \
# 0                           268.8                            -
# 1                           233.4                            -
# 2                           281.7                        102.7
# 3                           343.4                        200.8
# 4                           322.8                        213.5
#
#   Total Eclipse Duration (m)
# 0                          -
# 1                          -
# 2                          -
# 3                          -
# 4                       98.2

# %% [markdown]
# # Exploração dos Dados e Pré-Processamento (Eclipse Lunar)

# %%
dfLunar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12064 entries, 0 to 12063
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Catalog Number                  12064 non-null  int64
#  1   Calendar Date                   12064 non-null  object
#  2   Eclipse Time                    12064 non-null  object
#  3   Delta T (s)                     12064 non-null  int64
#  4   Lunation Number                 12064 non-null  int64
#  5   Saros Number                    12064 non-null  int64
#  6   Eclipse Type                    12064 non-null  object
#  7   Quincena Solar Eclipse          12064 non-null  object
#  8   Gamma                           12064 non-null  float64
#  9   Penumbral Magnitude             12064 non-null  float64
#  10  Umbral Magnitude                12064 non-null  float64
#  11  Latitude                        12064 non-null  object
#  12  Longitude                       12064 non-null  object
#  13  Penumbral Eclipse Duration (m)  12064 non-null  float64
#  14  Partial Eclipse Duration (m)    12064 non-null  object
#  15  Total Eclipse Duration (m)      12064 non-null  object
# dtypes: float64(4), int64(4), object(8)
# memory usage: 1.5+ MB

# %%
dfLunar.isnull().values.any()
# Out:
# False

# %%
dfLunar.describe()
# Out:
#        Catalog Number   Delta T (s)  Lunation Number  Saros Number  \
# count    12064.000000  12064.000000     12064.000000  12064.000000
# mean      6032.500000  12116.476044    -18531.392822     80.505056
# std       3482.721158  13584.785584     17887.218741     48.416007
# min          1.000000     -6.000000    -49456.000000    -20.000000
# 25%       3016.750000    962.000000    -33923.250000     40.000000
# 50%       6032.500000   5597.000000    -18445.500000     80.000000
# 75%       9048.250000  20901.500000     -3067.750000    121.000000
# max      12064.000000  46437.000000     12378.000000    183.000000
#
#               Gamma  Penumbral Magnitude  Umbral Magnitude  \
# count  12064.000000         12064.000000      12064.000000
# mean       0.002490             1.418656          0.400175
# std        0.910505             0.832263          0.832954
# min       -1.582700             0.000400         -1.095800
# 25%       -0.788825             0.684425         -0.334000
# 50%        0.001750             1.417450          0.400450
# 75%        0.791725             2.136900          1.117925
# max        1.579100             2.908900          1.882100
#
#        Penumbral Eclipse Duration (m)
# count                    12064.000000
# mean                       269.971941
# std                         79.945444
# min                          5.200000
# 25%                        223.100000
# 50%                        295.000000
# 75%                        327.800000
# max                        379.500000

# %%
dfLunar.drop(['Delta T (s)','Gamma'],axis=1,inplace=True)
dfLunar.head()
# Out:
#    Catalog Number      Calendar Date Eclipse Time  Lunation Number  \
# 0               1      -1999 June 26     14:13:28           -49456
# 1               2  -1999 November 21     20:23:49           -49451
# 2               3       -1998 May 17     05:47:36           -49445
# 3               4  -1998 November 11     05:15:58           -49439
# 4               5        -1997 May 6     18:57:01           -49433
#
#    Saros Number Eclipse Type Quincena Solar Eclipse  Penumbral Magnitude  \
# 0            17            N                     t-               0.8791
# 1           -16            N                     -a               0.8143
# 2           -11            P                     -t               1.2105
# 3            -6            P                     -a               2.0382
# 4            -1           T+                     pp               2.6513
#
#    Umbral Magnitude Latitude Longitude  Penumbral Eclipse Duration (m)  \
# 0           -0.1922      24S       22W                           268.8
# 1           -0.1921      15N       98W                           233.4
# 2            0.2069      13S       89E                           281.7
# 3            0.9740      12N      113E                           343.4
# 4            1.6963      11S       92W                           322.8
#
#   Partial Eclipse Duration (m) Total Eclipse Duration (m)
# 0                            -                          -
# 1                            -                          -
# 2                        102.7                          -
# 3                        200.8                          -
# 4                        213.5                       98.2

# %%
print(dfLunar['Eclipse Type'].unique())
print(dfLunar['Quincena Solar Eclipse'].unique())
# Out:
# ['N' 'P' 'T+' 'T-' 'T' 'Nx' 'Ne' 'Nb']
# ['t-' '-a' '-t' 'pp' 'a-' 'p-' 'h-' '-p' '-h' 'tp' 'pt']

# %%
dfLunar['Eclipse Type'] = pd.factorize(dfLunar['Eclipse Type'])[0] + 1
dfLunar['Quincena Solar Eclipse'] = pd.factorize(dfLunar['Quincena Solar Eclipse'])[0] + 1
dfLunar.head()
# Out:
#    Catalog Number      Calendar Date Eclipse Time  Lunation Number  \
# 0               1      -1999 June 26     14:13:28           -49456
# 1               2  -1999 November 21     20:23:49           -49451
# 2               3       -1998 May 17     05:47:36           -49445
# 3               4  -1998 November 11     05:15:58           -49439
# 4               5        -1997 May 6     18:57:01           -49433
#
#    Saros Number  Eclipse Type  Quincena Solar Eclipse  Penumbral Magnitude  \
# 0            17             1                       1               0.8791
# 1           -16             1                       2               0.8143
# 2           -11             2                       3               1.2105
# 3            -6             2                       2               2.0382
# 4            -1             3                       4               2.6513
#
#    Umbral Magnitude Latitude Longitude  Penumbral Eclipse Duration (m)  \
# 0           -0.1922      24S       22W                           268.8
# 1           -0.1921      15N       98W                           233.4
# 2            0.2069      13S       89E                           281.7
# 3            0.9740      12N      113E                           343.4
# 4            1.6963      11S       92W                           322.8
#
#   Partial Eclipse Duration (m) Total Eclipse Duration (m)
# 0                            -                          -
# 1                            -                          -
# 2                        102.7                          -
# 3                        200.8                          -
# 4                        213.5                       98.2

# %%
dfLunar2=dfLunar
dfLunar2['Partial Eclipse Duration (m)'].str.contains('-')
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 12059    False
# 12060    False
# 12061     True
# 12062     True
# 12063     True
# Name: Partial Eclipse Duration (m), Length: 12064, dtype: bool

# %%
dfLunar3= dfLunar2['Partial Eclipse Duration (m)']
dfLunar3.replace('-', np.nan,inplace=True)
dfLunar3=dfLunar3.astype(float)
val = dfLunar3.mean(axis=0,skipna = True)
print(val)
# Out:
# 174.76808482956025

# %%
dfLunar2['Partial Eclipse Duration (m)'].replace(np.nan, val,inplace=True)
dfLunar2['Partial Eclipse Duration (m)']=pd.to_numeric(dfLunar2["Partial Eclipse Duration (m)"])

# %%
dfLunar3= dfLunar2['Total Eclipse Duration (m)']
dfLunar3.replace('-', np.nan,inplace=True)
dfLunar3=dfLunar3.astype(float)
val = dfLunar3.mean(axis=0,skipna = True)
print(val)
dfLunar2['Total Eclipse Duration (m)'].replace(np.nan, val,inplace=True)
dfLunar2['Total Eclipse Duration (m)']=pd.to_numeric(dfLunar2["Total Eclipse Duration (m)"])
# Out:
# 80.82428858867489

# %%
dfLunar2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12064 entries, 0 to 12063
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Catalog Number                  12064 non-null  int64
#  1   Calendar Date                   12064 non-null  object
#  2   Eclipse Time                    12064 non-null  object
#  3   Lunation Number                 12064 non-null  int64
#  4   Saros Number                    12064 non-null  int64
#  5   Eclipse Type                    12064 non-null  int64
#  6   Quincena Solar Eclipse          12064 non-null  int64
#  7   Penumbral Magnitude             12064 non-null  float64
#  8   Umbral Magnitude                12064 non-null  float64
#  9   Latitude                        12064 non-null  object
#  10  Longitude                       12064 non-null  object
#  11  Penumbral Eclipse Duration (m)  12064 non-null  float64
#  12  Partial Eclipse Duration (m)    12064 non-null  float64
#  13  Total Eclipse Duration (m)      12064 non-null  float64
# dtypes: float64(5), int64(5), object(4)
# memory usage: 1.3+ MB

# %%
dfLunar2.head()
# Out:
#    Catalog Number      Calendar Date Eclipse Time  Lunation Number  \
# 0               1      -1999 June 26     14:13:28           -49456
# 1               2  -1999 November 21     20:23:49           -49451
# 2               3       -1998 May 17     05:47:36           -49445
# 3               4  -1998 November 11     05:15:58           -49439
# 4               5        -1997 May 6     18:57:01           -49433
#
#    Saros Number  Eclipse Type  Quincena Solar Eclipse  Penumbral Magnitude  \
# 0            17             1                       1               0.8791
# 1           -16             1                       2               0.8143
# 2           -11             2                       3               1.2105
# 3            -6             2                       2               2.0382
# 4            -1             3                       4               2.6513
#
#    Umbral Magnitude Latitude Longitude  Penumbral Eclipse Duration (m)  \
# 0           -0.1922      24S       22W                           268.8
# 1           -0.1921      15N       98W                           233.4
# 2            0.2069      13S       89E                           281.7
# 3            0.9740      12N      113E                           343.4
# 4            1.6963      11S       92W                           322.8
#
#    Partial Eclipse Duration (m)  Total Eclipse Duration (m)
# 0                    174.768085                   80.824289
# 1                    174.768085                   80.824289
# 2                    102.700000                   80.824289
# 3                    200.800000                   80.824289
# 4                    213.500000                   98.200000

# %%
dfLunar2['Calendar Date']=dfLunar2['Calendar Date'].str.replace('-', '')
dfLunar2.head()
# Out:
#    Catalog Number     Calendar Date Eclipse Time  Lunation Number  \
# 0               1      1999 June 26     14:13:28           -49456
# 1               2  1999 November 21     20:23:49           -49451
# 2               3       1998 May 17     05:47:36           -49445
# 3               4  1998 November 11     05:15:58           -49439
# 4               5        1997 May 6     18:57:01           -49433
#
#    Saros Number  Eclipse Type  Quincena Solar Eclipse  Penumbral Magnitude  \
# 0            17             1                       1               0.8791
# 1           -16             1                       2               0.8143
# 2           -11             2                       3               1.2105
# 3            -6             2                       2               2.0382
# 4            -1             3                       4               2.6513
#
#    Umbral Magnitude Latitude Longitude  Penumbral Eclipse Duration (m)  \
# 0           -0.1922      24S       22W                           268.8
# 1           -0.1921      15N       98W                           233.4
# 2            0.2069      13S       89E                           281.7
# 3            0.9740      12N      113E                           343.4
# 4            1.6963      11S       92W                           322.8
#
#    Partial Eclipse Duration (m)  Total Eclipse Duration (m)
# 0                    174.768085                   80.824289
# 1                    174.768085                   80.824289
# 2                    102.700000                   80.824289
# 3                    200.800000                   80.824289
# 4                    213.500000                   98.200000

# %%
dfLunar2['Eclipse Datetime']=dfLunar2['Calendar Date']+' '+dfLunar2['Eclipse Time']
dfLunar2.head()
# Out:
#    Catalog Number     Calendar Date Eclipse Time  Lunation Number  \
# 0               1      1999 June 26     14:13:28           -49456
# 1               2  1999 November 21     20:23:49           -49451
# 2               3       1998 May 17     05:47:36           -49445
# 3               4  1998 November 11     05:15:58           -49439
# 4               5        1997 May 6     18:57:01           -49433
#
#    Saros Number  Eclipse Type  Quincena Solar Eclipse  Penumbral Magnitude  \
# 0            17             1                       1               0.8791
# 1           -16             1                       2               0.8143
# 2           -11             2                       3               1.2105
# 3            -6             2                       2               2.0382
# 4            -1             3                       4               2.6513
#
#    Umbral Magnitude Latitude Longitude  Penumbral Eclipse Duration (m)  \
# 0           -0.1922      24S       22W                           268.8
# 1           -0.1921      15N       98W                           233.4
# 2            0.2069      13S       89E                           281.7
# 3            0.9740      12N      113E                           343.4
# 4            1.6963      11S       92W                           322.8
#
#    Partial Eclipse Duration (m)  Total Eclipse Duration (m)  \
# 0                    174.768085                   80.824289
# 1                    174.768085                   80.824289
# 2                    102.700000                   80.824289
# 3                    200.800000                   80.824289
# 4                    213.500000                   98.200000
#
#             Eclipse Datetime
# 0      1999 June 26 14:13:28
# 1  1999 November 21 20:23:49
# 2       1998 May 17 05:47:36
# 3  1998 November 11 05:15:58
# 4        1997 May 6 18:57:01

# %%
dfLunar2['Eclipse Datetime']=pd.to_datetime(dfLunar2['Eclipse Datetime'],errors='coerce')
dfLunar2['Eclipse Datetime']=pd.to_numeric(dfLunar2['Eclipse Datetime'],errors='coerce')
dfLunar2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12064 entries, 0 to 12063
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Catalog Number                  12064 non-null  int64
#  1   Calendar Date                   12064 non-null  object
#  2   Eclipse Time                    12064 non-null  object
#  3   Lunation Number                 12064 non-null  int64
#  4   Saros Number                    12064 non-null  int64
#  5   Eclipse Type                    12064 non-null  int64
#  6   Quincena Solar Eclipse          12064 non-null  int64
#  7   Penumbral Magnitude             12064 non-null  float64
#  8   Umbral Magnitude                12064 non-null  float64
#  9   Latitude                        12064 non-null  object
#  10  Longitude                       12064 non-null  object
#  11  Penumbral Eclipse Duration (m)  12064 non-null  float64
#  12  Partial Eclipse Duration (m)    12064 non-null  float64
#  13  Total Eclipse Duration (m)      12064 non-null  float64
#  14  Eclipse Datetime                12064 non-null  int64
# dtypes: float64(5), int64(6), object(4)
# memory usage: 1.4+ MB

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(dfLunar2.corr(),   #.corr() traz a correlação de Pearson, mostrando um relacionamento linear entre as variáveis
            annot = True,
            fmt = '.2f',
            cmap='Blues')
plt.title('Correlação entre variáveis do dataset de Eclipse Lunar')
plt.show()

# %%
dfLunar2.drop(['Calendar Date','Eclipse Time','Latitude','Longitude','Eclipse Datetime','Partial Eclipse Duration (m)','Total Eclipse Duration (m)','Quincena Solar Eclipse'],axis=1,inplace=True)

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(dfLunar2.corr(),   #.corr() traz a correlação de Pearson, mostrando um relacionamento linear entre as variáveis
            annot = True,
            fmt = '.2f',
            cmap='Blues')
plt.title('Correlação entre variáveis do dataset de Eclipse Lunar')
plt.show()
